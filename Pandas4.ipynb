# %% [markdown]
# <a href="https://colab.research.google.com/github/KShikha19/PY/blob/main/Pandas4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 49.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 58.1MB/s]

# %%
import pandas as pd
import numpy as np

movies = pd.read_csv('movies.csv', index_col=0)
directors = pd.read_csv('directors.csv', index_col=0)

data = movies.merge(directors, how='left', left_on='director_id',right_on='id')
data.drop(['director_id','id_y'],axis=1,inplace=True)

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#tell me the movies directed by high budget directors
#most productive directors
#most risky movies

# %%
#high budget directors => movies

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
#find the details of all the movies directed by high budget directors
#high budget => atleast 1 movie with budget > 100M

# %%
data['budget'] > 100000000
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: budget, Length: 1465, dtype: bool

# %%
data[data['budget'] > 100000000] #masking
# Out:
#       id_x     budget  popularity     revenue  \
# 0    43597  237000000         150  2787965087
# 1    43598  300000000         139   961000000
# 2    43599  245000000         107   880674609
# 3    43600  250000000         112  1084939099
# 4    43602  258000000         115   890871626
# ..     ...        ...         ...         ...
# 185  43897  105000000          58   121214377
# 186  43898  102000000          73   130482868
# 201  43929  115000000          41   274703340
# 290  44088  130000000          50   117831631
# 328  44162  150000000          47   919838758
#
#                                         title  vote_average  vote_count  year  \
# 0                                      Avatar           7.2       11800  2009
# 1    Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                     Spectre           6.3        4466  2015
# 3                       The Dark Knight Rises           7.6        9106  2012
# ...

# %%
dir_max_budget = data.groupby('director_name')['budget'].max()

# %%
dir_max_budget
# Out:
# director_name
# Adam McKay                     100000000
# Adam Shankman                   80000000
# Alejandro González Iñárritu    135000000
# Alex Proyas                    140000000
# Alexander Payne                 30000000
#                                  ...
# Wes Craven                      40000000
# Wolfgang Petersen              175000000
# Woody Allen                     30000000
# Zack Snyder                    250000000
# Zhang Yimou                     94000000
# Name: budget, Length: 199, dtype: int64

# %%
dir_max_budget > 100000000
# Out:
# director_name
# Adam McKay                     False
# Adam Shankman                  False
# Alejandro González Iñárritu     True
# Alex Proyas                     True
# Alexander Payne                False
#                                ...
# Wes Craven                     False
# Wolfgang Petersen               True
# Woody Allen                    False
# Zack Snyder                     True
# Zhang Yimou                    False
# Name: budget, Length: 199, dtype: bool

# %%
dir_max_budget[dir_max_budget > 100000000]
# Out:
# director_name
# Alejandro González Iñárritu    135000000
# Alex Proyas                    140000000
# Andrew Adamson                 225000000
# Ang Lee                        137000000
# Barry Sonnenfeld               225000000
#                                  ...
# Tim Story                      130000000
# Tom Shadyac                    175000000
# Tom Tykwer                     102000000
# Wolfgang Petersen              175000000
# Zack Snyder                    250000000
# Name: budget, Length: 79, dtype: int64

# %%
names = dir_max_budget[dir_max_budget > 100000000].index

# %%
dir_max_budget[dir_max_budget > 100000000].values
# Out:
# array([135000000, 140000000, 225000000, 137000000, 225000000, 120000000,
#        210000000, 270000000, 125000000, 180000000, 250000000, 125000000,
#        175000000, 150000000, 178000000, 140000000, 160000000, 110000000,
#        150000000, 300000000, 180000000, 125000000, 237000000, 120000000,
#        190000000, 160000000, 150000000, 125000000, 160000000, 125000000,
#        200000000, 130000000, 150000000, 150000000, 185000000, 150000000,
#        175000000, 140000000, 176000003, 150000000, 150000000, 200000000,
#        200000000, 170000000, 200000000, 155000000, 210000000, 107000000,
#        150000000, 155000000, 120000000, 105000000, 130000000, 209000000,
#        250000000, 110000000, 110000000, 140000000, 200000000, 145000000,
#        380000000, 145000000, 130000000, 200000000, 116000000, 200000000,
#        150000000, 245000000, 258000000, 150000000, 115000000, 110000000,
#        185000000, 200000000, 130000000, 175000000, 102000000, 175000000,
#        250000000])

# %%
df_budget = dir_max_budget[dir_max_budget > 100000000].reset_index()

# %%
df_budget #try to perform join on this df and data to get the movies details
# Out:
#                   director_name     budget
# 0   Alejandro González Iñárritu  135000000
# 1                   Alex Proyas  140000000
# 2                Andrew Adamson  225000000
# 3                       Ang Lee  137000000
# 4              Barry Sonnenfeld  225000000
# ..                          ...        ...
# 74                    Tim Story  130000000
# 75                  Tom Shadyac  175000000
# 76                   Tom Tykwer  102000000
# 77            Wolfgang Petersen  175000000
# 78                  Zack Snyder  250000000
#
# [79 rows x 2 columns]

# %%
df_budget['director_name']
# Out:
# 0     Alejandro González Iñárritu
# 1                     Alex Proyas
# 2                  Andrew Adamson
# 3                         Ang Lee
# 4                Barry Sonnenfeld
#                  ...
# 74                      Tim Story
# 75                    Tom Shadyac
# 76                     Tom Tykwer
# 77              Wolfgang Petersen
# 78                    Zack Snyder
# Name: director_name, Length: 79, dtype: object

# %%
names #high budget directors names
# Out:
# Index(['Alejandro González Iñárritu', 'Alex Proyas', 'Andrew Adamson',
#        'Ang Lee', 'Barry Sonnenfeld', 'Bill Condon', 'Brett Ratner',
#        'Bryan Singer', 'Chris Columbus', 'Chris Weitz', 'Christopher Nolan',
#        'Darren Aronofsky', 'David Ayer', 'David Fincher', 'Doug Liman',
#        'Edward Zwick', 'Francis Lawrence', 'Frank Coraci', 'George Miller',
#        'Gore Verbinski', 'Guillermo del Toro', 'Guy Ritchie', 'James Cameron',
#        'James Mangold', 'James Wan', 'Jan de Bont', 'Joe Wright',
#        'Joel Schumacher', 'John McTiernan', 'John Woo', 'Jon Favreau',
#        'Jon M. Chu', 'Jon Turteltaub', 'Jonathan Liebesman', 'Justin Lin',
#        'Kenneth Branagh', 'Kevin Reynolds', 'Lee Tamahori', 'Lilly Wachowski',
#        'Louis Leterrier', 'M. Night Shyamalan', 'Marc Forster',
#        'Martin Campbell', 'Martin Scorsese', 'McG', 'Michael Apted',
#        'Michael Bay', 'Michael Mann', 'Mike Newell', 'Oliver Stone',
# ...

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data['director_name'].isin(names)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1460     True
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: director_name, Length: 1465, dtype: bool

# %%
data[data['director_name'].isin(names)]['title']
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                   Spider-Man 3
#                           ...
# 1450                                     Mad Max
# 1451                                    Swingers
# 1452                                       Three
# 1458                                          Pi
# 1460                              The Last Waltz
# Name: title, Length: 636, dtype: object

# %%
#smarter ? => reduce the number of steps
def high_budget(g):
  return g['budget'].max() > 100000000 #79 groups

# %%
data.groupby('director_name').filter(high_budget)
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1450  48267     400000          33   100000000
# 1451  48268     200000          13     4505922
# 1452  48274          0           5     2611555
# 1458  48335      60000          27     3221152
# 1460  48363          0           3      321952
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#using lambda in single line
data.groupby('director_name').filter(lambda g:g['budget'].max()>100000000)
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1450  48267     400000          33   100000000
# 1451  48268     200000          13     4505922
# 1452  48274          0           5     2611555
# 1458  48335      60000          27     3221152
# 1460  48363          0           3      321952
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#high risk movies
#if a movie has higher budget than avg revenue for that director => high risk movies

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data['budget'].mean()
# Out:
# np.float64(48022946.87986348)

# %%
data['revenue'].mean()
# Out:
# np.float64(143253923.0750853)

# %%
def risky(x):
  x['risky'] = x['budget'] - x['revenue'].mean() > 0
  return x

# %%
data.groupby('director_name').apply(risky)
# Out:
# <ipython-input-45-547b10dbd5ed>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data.groupby('director_name').apply(risky)
#                      id_x     budget  popularity    revenue  \
# director_name
# Adam McKay    176   43882  100000000          24  170432927
#               323   44151   72500000          12  162966177
#               366   44236   65000000          22  128107642
#               505   44503   50000000          38  173649015
#               839   45301   28000000          57  133346506
# ...                   ...        ...         ...        ...
# Zhang Yimou   590   44692        110           9          0
#               604   44733   31000000          23  177394432
# ...

# %%
data_risky = data.groupby('director_name',group_keys=False).apply(risky)
# Out:
# <ipython-input-46-20248bae7463>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data_risky = data.groupby('director_name',group_keys=False).apply(risky)

# %%
data_risky
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data_risky['risky'].value_counts()
# Out:
# risky
# False    1334
# True      131
# Name: count, dtype: int64

# %%
data_risky['risky']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: risky, Length: 1465, dtype: bool

# %%
#masking
data_risky[data_risky['risky'] == True]
# Out:
#        id_x     budget  popularity     revenue  \
# 7     43608  200000000         107   586090727
# 12    43614  380000000         135  1045713802
# 15    43618  200000000          37   310669540
# 20    43624  209000000          64   303025485
# 24    43630  210000000           3   459359555
# ...     ...        ...         ...         ...
# 1347  47224    5000000           7     3263585
# 1349  47229    5000000           3     4842699
# 1351  47233    5000000           6           0
# 1356  47263   15000000          10           0
# 1383  47453    3500000           4           0
#
#                                             title  vote_average  vote_count  \
# 7                               Quantum of Solace           6.1        2965
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 15                                     Robin Hood           6.2        1398
# 20                                     Battleship           5.5        2114
# ...

# %% [markdown]
# #most productive directors

# %%
#more work(more movies) => more productive

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data['director_name'].value_counts()
# Out:
# director_name
# Steven Spielberg       26
# Martin Scorsese        19
# Clint Eastwood         19
# Woody Allen            18
# Spike Lee              16
#                        ..
# Mike Leigh              5
# Brad Anderson           5
# Michael Polish          5
# Darren Lynn Bousman     5
# Nicole Holofcener       5
# Name: count, Length: 199, dtype: int64

# %%
data_agg = data.groupby('director_name').aggregate({'year':['min','max'],'title':['count']})

# %%
data_agg #multi level index
# Out:
#                              year       title
#                               min   max count
# director_name
# Adam McKay                   2004  2015     6
# Adam Shankman                2001  2012     8
# Alejandro González Iñárritu  2000  2015     6
# Alex Proyas                  1994  2016     5
# Alexander Payne              1999  2013     5
# ...                           ...   ...   ...
# Wes Craven                   1984  2011    10
# Wolfgang Petersen            1981  2006     7
# Woody Allen                  1977  2013    18
# Zack Snyder                  2004  2016     7
# Zhang Yimou                  2002  2014     6
#
# [199 rows x 3 columns]

# %%
data_agg.columns
# Out:
# MultiIndex([( 'year',   'min'),
#             ( 'year',   'max'),
#             ('title', 'count')],
#            )

# %%
data_agg['year']
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
data_agg['year']['max']
# Out:
# director_name
# Adam McKay                     2015
# Adam Shankman                  2012
# Alejandro González Iñárritu    2015
# Alex Proyas                    2016
# Alexander Payne                2013
#                                ...
# Wes Craven                     2011
# Wolfgang Petersen              2006
# Woody Allen                    2013
# Zack Snyder                    2016
# Zhang Yimou                    2014
# Name: max, Length: 199, dtype: int64

# %%
data_agg[('year','min')]
# Out:
# director_name
# Adam McKay                     2004
# Adam Shankman                  2001
# Alejandro González Iñárritu    2000
# Alex Proyas                    1994
# Alexander Payne                1999
#                                ...
# Wes Craven                     1984
# Wolfgang Petersen              1981
# Woody Allen                    1977
# Zack Snyder                    2004
# Zhang Yimou                    2002
# Name: (year, min), Length: 199, dtype: int64

# %%
data_agg['title']['count']
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: count, Length: 199, dtype: int64

# %%
#single level indexing
data_agg.head()
# Out:
#                              year       title
#                               min   max count
# director_name
# Adam McKay                   2004  2015     6
# Adam Shankman                2001  2012     8
# Alejandro González Iñárritu  2000  2015     6
# Alex Proyas                  1994  2016     5
# Alexander Payne              1999  2013     5

# %%
data_agg.columns  = ['year_min','year_max','title_count']
data_agg
# Out:
#                              year_min  year_max  title_count
# director_name
# Adam McKay                       2004      2015            6
# Adam Shankman                    2001      2012            8
# Alejandro González Iñárritu      2000      2015            6
# Alex Proyas                      1994      2016            5
# Alexander Payne                  1999      2013            5
# ...                               ...       ...          ...
# Wes Craven                       1984      2011           10
# Wolfgang Petersen                1981      2006            7
# Woody Allen                      1977      2013           18
# Zack Snyder                      2004      2016            7
# Zhang Yimou                      2002      2014            6
#
# [199 rows x 3 columns]

# %%
data_agg.reset_index(inplace=True)

# %%
data_agg
# Out:
#                    director_name  year_min  year_max  title_count
# 0                     Adam McKay      2004      2015            6
# 1                  Adam Shankman      2001      2012            8
# 2    Alejandro González Iñárritu      2000      2015            6
# 3                    Alex Proyas      1994      2016            5
# 4                Alexander Payne      1999      2013            5
# ..                           ...       ...       ...          ...
# 194                   Wes Craven      1984      2011           10
# 195            Wolfgang Petersen      1981      2006            7
# 196                  Woody Allen      1977      2013           18
# 197                  Zack Snyder      2004      2016            7
# 198                  Zhang Yimou      2002      2014            6
#
# [199 rows x 4 columns]

# %%
data_agg['active_years'] = data_agg['year_max']-data_agg['year_min']
data_agg
# Out:
#                    director_name  year_min  year_max  title_count  \
# 0                     Adam McKay      2004      2015            6
# 1                  Adam Shankman      2001      2012            8
# 2    Alejandro González Iñárritu      2000      2015            6
# 3                    Alex Proyas      1994      2016            5
# 4                Alexander Payne      1999      2013            5
# ..                           ...       ...       ...          ...
# 194                   Wes Craven      1984      2011           10
# 195            Wolfgang Petersen      1981      2006            7
# 196                  Woody Allen      1977      2013           18
# 197                  Zack Snyder      2004      2016            7
# 198                  Zhang Yimou      2002      2014            6
#
#      active_years
# 0              11
# 1              11
# 2              15
# 3              22
# 4              14
# ..            ...
# 194            27
# ...

# %%
data_agg['movies_per_year'] = data_agg['title_count']/data_agg['active_years']
data_agg
# Out:
#                    director_name  year_min  year_max  title_count  \
# 0                     Adam McKay      2004      2015            6
# 1                  Adam Shankman      2001      2012            8
# 2    Alejandro González Iñárritu      2000      2015            6
# 3                    Alex Proyas      1994      2016            5
# 4                Alexander Payne      1999      2013            5
# ..                           ...       ...       ...          ...
# 194                   Wes Craven      1984      2011           10
# 195            Wolfgang Petersen      1981      2006            7
# 196                  Woody Allen      1977      2013           18
# 197                  Zack Snyder      2004      2016            7
# 198                  Zhang Yimou      2002      2014            6
#
#      active_years  movies_per_year
# 0              11         0.545455
# 1              11         0.727273
# 2              15         0.400000
# ...

# %%
data_agg.sort_values(by='movies_per_year',ascending=False,inplace=True)

# %%
data_agg
# Out:
#         director_name  year_min  year_max  title_count  active_years  \
# 190       Tyler Perry      2006      2013            9             7
# 73    Jason Friedberg      2006      2010            5             4
# 169        Shawn Levy      2002      2014           11            12
# 158  Robert Rodriguez      1992      2014           16            22
# 1       Adam Shankman      2001      2012            8            11
# ..                ...       ...       ...          ...           ...
# 104   Lawrence Kasdan      1985      2012            5            27
# 109        Luc Besson      1985      2014            5            29
# 117     Michael Apted      1980      2010            5            30
# 157    Robert Redford      1980      2010            5            30
# 170      Sidney Lumet      1976      2006            5            30
#
#      movies_per_year
# 190         1.285714
# 73          1.250000
# 169         0.916667
# 158         0.727273
# 1           0.727273
# ...

# %%
#reset index

# %%
#movies directed by the most profitable directors (atleast one movie directed by him having profit > 200M)

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#workin gon pfizer dataset => pivot,melting

# %%
import pandas as pd

data = {
    'name': ['Elon', 'Jeff', 'Bill', 'Falguni'],
    'gender': ['M', 'F', 'M', 'F'],
    'income': [53000.0, 28000.0, 25000.0, 44000.0]
}

df = pd.DataFrame(data)
df
# Out:
#       name gender   income
# 0     Elon      M  53000.0
# 1     Jeff      F  28000.0
# 2     Bill      M  25000.0
# 3  Falguni      F  44000.0

# %%
grouped = df.groupby('gender')
grouped['income'].mean()
# Out:
# gender
# F    36000.0
# M    39000.0
# Name: income, dtype: float64

# %%
grouped.aggregate({'income':['mean']})
# Out:
#          income
#            mean
# gender
# F       36000.0
# M       39000.0

# %%
grouped['income'].aggregate('mean')
# Out:
# gender
# F    36000.0
# M    39000.0
# Name: income, dtype: float64
